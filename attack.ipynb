# %%
# Given Values

p = ...
g = ...
h = ...
a = ...
c = 
t = 

# %% [markdown]
# # Problem Analysis
#
# - As for r 2^50 values are possible and only one transcript is available
# - Hashing has no role in the security of exrtracting the value of r
# - phi(p) = p - 1
# - Schnorr security completely collapses if the nonce 𝑟, r is small or biased; even a 50-bit nonce allows recovery of the secret 𝑥, x via algebraic attacks
#
# We will use pollards kangaroo algorithm for this case because :
# - Schnorr security assumes uniform random nonces
# - Pollard Kangaroo is designed for this exact situation
# - Hashing the challenge does nothing to fix bad randomness

# %%
def recover_r_kangaroo(g, a, p, bits=50):
    g = Mod(g, p)
    a = Mod(a, p)

    r = discrete_log(
        a,
        g,
        bounds=(0, Integer(2)^bits),
        operation='*',
        algorithm='lambda'
    )
    return Integer(r)

def recover_x(g, h, p, c, t, r):
    """
    Solve t = r + c*x mod (p-1)
    """
    order = p - 1
    d = gcd(c, order)

    if (t - r) % d != 0:
        raise ValueError("No solution for x")

    c_ = c // d
    rhs_ = (t - r) // d
    order_ = order // d

    x0 = (rhs_ * inverse_mod(c_, order_)) % order_

    for k in range(d):
        x = (x0 + k * order_) % order
        if power_mod(g, x, p) == h:
            return Integer(x)

    raise ValueError("x not found")

# %%
print("Recovering r (this may take few minutes)......")
r = recover_r_kangaroo(g, a, p, bits=50)
print("Recovered r:", r)

print("Recovering x...")
x = recover_x(g, h, p, c, t, r)
print("Recovered x:", x)
# Out:
# Recovering r (this may take few minutes)......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print("Recovering r (this may take few minutes)......")
# ----> 2 r = recover_r_kangaroo(g, a, p, bits=Integer(50))
#       3 print("Recovered r:", r)
#       5 print("Recovering x...")
#
# Cell In[2], line 3, in recover_r_kangaroo(g, a, q, bits)
#       1 def recover_r_kangaroo(g, a, q, bits=Integer(50)):
#       2     upper = min(Integer(Integer(2))**bits, q)
# ----> 3     r = discrete_log(a, g, ord=q, bounds=(Integer(0), upper), algorithm='lambda')
#       4     return Integer(r)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/groups/generic.py:926, in discrete_log(a, base, ord, bounds, operation, identity, inverse, op, algorithm)
#     924 if base == power(base, 0) and a != base:
# ...
